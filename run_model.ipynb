# %%
from get_optimal_portfolio import get_portfolio

tickers = ["NVDA", "DELL", "NVO", "GE", "MUFG", "AGI"]
# What is the minimum allocation per asset?
min_allocations = [0.0]*(len(tickers))
# What is the maximum allocation per asset
max_allocations = [1.0]*(len(tickers))
cash = True

get_portfolio(tickers, min_allocations, max_allocations, include_cash= cash)
